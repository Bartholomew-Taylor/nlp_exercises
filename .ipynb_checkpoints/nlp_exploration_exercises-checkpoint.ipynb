# %%
from requests import get
from bs4 import BeautifulSoup, SoupStrainer
import re
import unicodedata
import pandas as pd
import nltk
import prepare
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import os
from wordcloud import WordCloud
import json
from env import get_connection

# %%
url = get_connection('spam_db')

# %% [markdown]
# Load the spam data set.

# %%
#Define SQL query
query = '''
        SELECT *
        FROM spam
        '''

# %%
df = pd.read_sql(query, url, index_col='id')
df.head()
# Out:
#    label                                               text
# id
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
def clean_text(text, extra_stopwords=['r', 'u', '2', 'ltgt']):
    
    wnl = nltk.stem.WordNetLemmatizer()
    
    stopwords = nltk.corpus.stopwords.words('english') + extra_stopwords
    
    clean_text = (unicodedata.normalize('NFKD', text)
                   .encode('ascii', 'ignore')
                   .decode('utf-8', 'ignore')
                   .lower())
    
    words = re.sub(r'[^\w\s]', '', clean_text).split()
    
    return [wnl.lemmatize(word) for word in words if word not in stopwords]

# %%
ham_words = clean_text(' '.join(df[df['label'] == 'ham']['text']))
spam_words = clean_text(' '.join(df[df['label'] == 'spam']['text']))
all_words = clean_text(' '.join(df['text']))

# %% [markdown]
# Create and explore bigrams for the spam data. Visualize them with a word cloud. How do they compare with the ham bigrams?

# %%
ham_bigrams = pd.Series(nltk.ngrams(ham_words, 2))
ham_bigrams.head()
# Out:
# 0          (go, jurong)
# 1       (jurong, point)
# 2        (point, crazy)
# 3    (crazy, available)
# 4    (available, bugis)
# dtype: object

# %%
top_ham_bigrams = ham_bigrams.value_counts().head(10)
top_ham_bigrams
# Out:
# (call, later)      52
# (ill, call)        48
# (let, know)        42
# (sorry, ill)       39
# (dont, know)       32
# (good, morning)    31
# (new, year)        30
# (take, care)       26
# (im, going)        24
# (ok, lor)          22
# dtype: int64

# %%
spam_bigrams = pd.Series(nltk.ngrams(spam_words, 2))
spam_bigrams.head()
# Out:
# 0    (free, entry)
# 1    (entry, wkly)
# 2     (wkly, comp)
# 3      (comp, win)
# 4        (win, fa)
# dtype: object

# %%
top_spam_bigrams = spam_bigrams.value_counts().head(10)
top_spam_bigrams
# Out:
# (please, call)         44
# (customer, service)    27
# (po, box)              24
# (a1000, cash)          23
# (guaranteed, call)     23
# (prize, guaranteed)    22
# (send, stop)           19
# (selected, receive)    19
# (await, collection)    19
# (every, week)          19
# dtype: int64

# %% [markdown]
# Is there any overlap in the bigrams for the spam data and the ham data?

# %%
#not in the most frequent list

# %% [markdown]
# Create and explore with trigrams (i.e. a n-gram with an n of 3) for both the spam and ham data.

# %%
spam_trigrams = pd.Series(nltk.ngrams(spam_words, 3))
ham_trigrams = pd.Series(nltk.ngrams(ham_words, 3))

# %%
top_ham_trigrams = ham_trigrams.value_counts().head(10)
top_ham_trigrams
# Out:
# (ill, call, later)      42
# (sorry, ill, call)      38
# (happy, new, year)      19
# (pls, send, message)    13
# (cant, pick, phone)     12
# (right, pls, send)      12
# (phone, right, pls)     12
# (pick, phone, right)    12
# (hi, hi, hi)            11
# (x, x, x)                8
# dtype: int64

# %%
top_spam_trigrams = spam_trigrams.value_counts().head(10)
top_spam_trigrams
# Out:
# (prize, guaranteed, call)     21
# (call, customer, service)     15
# (land, line, claim)           14
# (reply, call, 08000930705)    14
# (private, 2003, account)      13
# (2003, account, statement)    13
# (camcorder, reply, call)      12
# (guaranteed, a1000, cash)     12
# (show, 800, unredeemed)       12
# (urgent, trying, contact)     11
# dtype: int64

# %% [markdown]
# Explore the blog articles using the techniques discussed in the exploration lesson.

# %%
url = 'https://codeup.com/blog/'
headers = {'User-Agent': 'Codeup Data Science'}
response = requests.get(url, headers=headers)

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n<head>\n\t<meta charset="UTF-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t<link rel="pingback" href="https://codeup.com/xmlrpc.php" />\n\n\t<script type="text/javascript">\n\t\tdocument.documentElement.className = \'js\';\n\t</script>\n\t\n\t<link rel="preconnect" href="https://fonts.gstatic.com" crossorigin /><script id="diviarea-loader">window.DiviPopupData=window.DiviAreaConfig={"zIndex":1000000,"animateSpeed":400,"triggerClassPrefix":"show-popup-","idAttrib":"data-popup","modalIndicatorClass":"is-modal","blockingIndicatorClass":"is-blocking","defaultShowCloseButton":true,"withCloseClass":"with-close","noCloseClass":"no-close","triggerCloseClass":"close","singletonClass":"single","darkModeClass":"dark","noShadowClass":"no-shadow","altCloseClass":"close-alt","popupSelector":".et_pb_section.popup","initializeOnEvent":"et_pb_after_init_modules","popupWrapperClass":"area-outer-wrap","fullHeightClass":"full-height","openPopupCla
# ...

# %%
cu_soup = BeautifulSoup(response.content, 'html.parser')
cu_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://codeup.com/xmlrpc.php" rel="pingback"/>
# <script type="text/javascript">
# 		document.documentElement.className = 'js';
# 	</script>
# ...

# %% [markdown]
# Explore the news articles using the techniques discussed in the exploration lesson. Use the category variable when exploring.

# %%
response2 = get('https://inshorts.com/en/read/business')
soup2 = BeautifulSoup(response2.content, 'html.parser')

# %%
titles = soup2.find_all('span', itemprop = 'headline')
titles[0]
# Out:
# <span itemprop="headline">Income Tax Dept raids Edelweiss Group, search underway at Mumbai premises</span>

# %%
summaries = soup2.find_all('div', itemprop = 'articleBody')
summaries[0]
# Out:
# <div itemprop="articleBody">The Income Tax Department is conducting raids on Edelweiss Group, an investment and financial services company co-founded by Rashesh Shah and Venkat Ramaswamy, ANI reported on Thursday. Searches are underway at premises linked to the group in Mumbai, it added. Male employees asked to stay back in the office, while female employees have been sent back, Mirror Now reported.</div>

# %%
def scrap_one_page(topic):
    base_url = 'https://inshorts.com/en/read/'
    response = get(base_url + topic)
    soup = BeautifulSoup(response.content, 'html.parser')
    titles = soup.find_all('span', itemprop = 'headline')
    summaries = soup.find_all('div', itemprop = 'articleBody')
    summary_list = []
    for i in range(len(titles)):
        temp_dict = {'category': topic,
                    'title': titles[i].text,
                    'content': summaries[i].text}
        summary_list.append(temp_dict)
    return summary_list

# %%
def get_news_articles(topic_list):
    file = 'news_articles.json'
    if os.path.exists(file):
        with open(file) as f:
            return json.load(f)
    final_list = []
    for topic in topic_list:
        final_list.extend(scrap_one_page(topic))
    with open(file, 'w') as f:
        json.dump(final_list, f)
    return final_list

# %%
list_topics = ['business', 'sports', 'technology', 'entertainment']

final_list = get_news_articles(list_topics)

# %%
final_df = pd.DataFrame(final_list)
final_df
# Out:
#          category                                              title  \
# 0        business  Sachin Tendulkar and his wife meet Bill Gates;...
# 1        business  'Best wishes to my classmate,' writes Gates in...
# 2        business  Ambanis should get Z+ security cover across In...
# 3        business  Apple supplier Foxlink's fire safety systems f...
# 4        business  People consuming 30 GB and paying almost nothi...
# ..            ...                                                ...
# 95  entertainment  Courteney gets star on H'wood Walk of Fame, An...
# 96  entertainment  Reactions to trailer are too special: Rani on ...
# 97  entertainment  It's been pretty psychotic: Shahid Kapoor on h...
# 98  entertainment  Was nervous dancing with Sridevi & Urmila: Ani...
# 99  entertainment  Was told I can either be composer, lyricist or...
#
#                                               content
# 0   Former cricketer Sachin Tendulkar and his wife...
# ...

# %%
news_stop = ['said', 'india']

# %%
business_words = clean_text(' '.join(final_df[final_df['category'] == 'business']['content']), news_stop)
entertainment_words = clean_text(' '.join(final_df[final_df['category'] == 'entertainment']['content']), news_stop)
sports_words = clean_text(' '.join(final_df[final_df['category'] == 'sports']['content']), news_stop)
technology_words = clean_text(' '.join(final_df[final_df['category'] == 'technology']['content']), news_stop)
all_words = clean_text(' '.join(final_df['content']), news_stop)

# %%
business_counts = pd.Series(business_words).value_counts()
sports_counts = pd.Series(sports_words).value_counts()
technology_counts = pd.Series(technology_words).value_counts()
entertainment_counts = pd.Series(entertainment_words).value_counts()

all_counts = pd.Series(all_words).value_counts()

# %%
word_freq = pd.concat([business_counts, sports_counts, technology_counts, 
                       entertainment_counts, all_counts], axis=1)
word_freq.head()
# Out:
#            0    1    2    3   4
# tuesday  9.0  1.0  5.0  1.0  16
# 2022     9.0  5.0  NaN  NaN  14
# crore    9.0  NaN  4.0  NaN  13
# year     8.0  3.0  5.0  3.0  19
# sector   8.0  NaN  2.0  NaN  10

# %%
word_freq.columns = ['business', 'sports', 'technology', 'entertainment', 'all']
word_freq.fillna(0, inplace=True)
word_freq.head()
# Out:
#          business  sports  technology  entertainment  all
# tuesday       9.0     1.0         5.0            1.0   16
# 2022          9.0     5.0         0.0            0.0   14
# crore         9.0     0.0         4.0            0.0   13
# year          8.0     3.0         5.0            3.0   19
# sector        8.0     0.0         2.0            0.0   10

# %%
#Plot the most frequent words and color by label
word_freq.sort_values('all', ascending=False).head(10).plot.bar(figsize=(16, 9))
plt.title('Most common words by category')
plt.ylabel('Count')
plt.xlabel('Most common words')
plt.xticks(rotation=45)
plt.show()

# %%
#Word cloud
all_cloud = WordCloud(background_color='white').generate(' '.join(all_words))
plt.figure(figsize=(12, 8))
plt.imshow(all_cloud)
plt.axis('off')
plt.show()
